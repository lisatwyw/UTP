# %% [markdown]
# <a href="https://colab.research.google.com/github/lisatwyw/unet_variants/blob/main/tf_U_Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import concatenate,add,Dense,BatchNormalization,Concatenate,Input,Dropout,Maximum,Activation,Dense,Flatten,Add,Multiply,Lambda
from tensorflow.keras.layers import MaxPooling3D,Conv3D,UpSampling3D,Conv3DTranspose
from tensorflow.keras.layers import MaxPooling2D,Conv2D,UpSampling2D,Conv2DTranspose
from tensorflow.keras.models import Model

# trivial test


o = Conv2D( 8, (1,1) )( Input( (224, 224, 3) ) )

# %% [markdown]
# # Shared components

# %%
def stack_bn_act( x, NF, KS, strides=(1,1) ):
  for i, k in enumerate( KS ):
    x = Conv2D( NF, k, padding='same', strides=strides )(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
  return x

def conv_block( x, NF, KS, strides=(1,1) ):

  o = Conv2D( NF, kernel_size= KS[0], strides=strides, padding='same' )(x)
  o = BatchNormalization()(o)
  o = Activation( 'relu' )(o)

  o = stack_bn_act(o, NF, KS[1:])
  return o

def deconv_block( x, NF, ks=2, strides=(1,1) ):
  o = Conv2DTranspose( NF, ks, strides=strides, padding='same' )(x)
  o = BatchNormalization()(o)
  o = Activation( 'relu' )(o)
  return o

# %% [markdown]
# # Admin variables and hyperparameters

# %%
AC = 'sigmoid'
BS = 8
NF = 16
NDIM=2
ks =(3)

ks_s=[ks]*len(nfilters)

vol = np.zeros( (65,224*3,224*3) )

IR=3
NZ,NX,NY = vol[:,::IR,::IR].shape

n_slices = 3
inp = Input( (NX, NY, n_slices) )

# %% [markdown]
# # Basic U-Net

# %%
o1 = conv_block( inp, NF,    ks_s ); p1 = MaxPooling2D()( o1 )
o2 = conv_block( p1,  NF*2,  ks_s ); p2 = MaxPooling2D()( o2 )
o3 = conv_block( p2,  NF*4,  ks_s ); p3 = MaxPooling2D()( o3 )
o4 = conv_block( p3,  NF*8,  ks_s ); p4 = MaxPooling2D()( o4 )
o5 = conv_block( p4,  NF*16, ks_s ); p5 = MaxPooling2D()( o5 )

o6 = conv_block( Concatenate()( [deconv_block( o5, NF*8, strides=(2,2) ), o4]), NF*8, ks_s )
o7 = conv_block( Concatenate()( [deconv_block( o6, NF*4, strides=(2,2) ), o3]), NF*4, ks_s )
o8 = conv_block( Concatenate()( [deconv_block( o7, NF*2, strides=(2,2) ), o2]), NF*2, ks_s )
o9 = conv_block( Concatenate()( [deconv_block( o8, NF*1, strides=(2,2) ), o1]), NF*1, ks_s )

out = Activation( AC )( Conv2D( 2, 1 )( o9 ) )
model = Model(inp, outputs=out )

# %%
model.summary()
# Out:
# Model: "model_35"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_114 (InputLayer)         [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_3393 (Conv2D)           (None, 224, 224, 16  448         ['input_114[0][0]']
#                                 )
#
#  batch_normalization_3533 (Batc  (None, 224, 224, 16  64         ['conv2d_3393[0][0]']
#  hNormalization)                )
#
#  activation_3424 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3533[0][0]'
#                                 )                                ]
#
#  conv2d_3394 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3424[0][0]']
#                                 )
#
#  batch_normalization_3534 (Batc  (None, 224, 224, 16  64         ['conv2d_3394[0][0]']
#  hNormalization)                )
#
#  activation_3425 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3534[0][0]'
#                                 )                                ]
#
#  conv2d_3395 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3425[0][0]']
#                                 )
#
#  batch_normalization_3535 (Batc  (None, 224, 224, 16  64         ['conv2d_3395[0][0]']
#  hNormalization)                )
#
#  activation_3426 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3535[0][0]'
#                                 )                                ]
#
#  conv2d_3396 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3426[0][0]']
#                                 )
#
#  batch_normalization_3536 (Batc  (None, 224, 224, 16  64         ['conv2d_3396[0][0]']
#  hNormalization)                )
#
#  activation_3427 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3536[0][0]'
#                                 )                                ]
#
#  conv2d_3397 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3427[0][0]']
#                                 )
#
#  batch_normalization_3537 (Batc  (None, 224, 224, 16  64         ['conv2d_3397[0][0]']
#  hNormalization)                )
#
#  activation_3428 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3537[0][0]'
#                                 )                                ]
#
#  max_pooling2d_657 (MaxPooling2  (None, 112, 112, 16  0          ['activation_3428[0][0]']
#  D)                             )
#
#  conv2d_3398 (Conv2D)           (None, 112, 112, 32  4640        ['max_pooling2d_657[0][0]']
#                                 )
#
#  batch_normalization_3538 (Batc  (None, 112, 112, 32  128        ['conv2d_3398[0][0]']
#  hNormalization)                )
#
#  activation_3429 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3538[0][0]'
#                                 )                                ]
#
#  conv2d_3399 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3429[0][0]']
#                                 )
#
#  batch_normalization_3539 (Batc  (None, 112, 112, 32  128        ['conv2d_3399[0][0]']
#  hNormalization)                )
#
#  activation_3430 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3539[0][0]'
#                                 )                                ]
#
#  conv2d_3400 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3430[0][0]']
#                                 )
#
#  batch_normalization_3540 (Batc  (None, 112, 112, 32  128        ['conv2d_3400[0][0]']
#  hNormalization)                )
#
#  activation_3431 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3540[0][0]'
#                                 )                                ]
#
#  conv2d_3401 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3431[0][0]']
#                                 )
#
#  batch_normalization_3541 (Batc  (None, 112, 112, 32  128        ['conv2d_3401[0][0]']
#  hNormalization)                )
#
#  activation_3432 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3541[0][0]'
#                                 )                                ]
#
#  conv2d_3402 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3432[0][0]']
#                                 )
#
#  batch_normalization_3542 (Batc  (None, 112, 112, 32  128        ['conv2d_3402[0][0]']
#  hNormalization)                )
#
#  activation_3433 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3542[0][0]'
#                                 )                                ]
#
#  max_pooling2d_658 (MaxPooling2  (None, 56, 56, 32)  0           ['activation_3433[0][0]']
#  D)
#
#  conv2d_3403 (Conv2D)           (None, 56, 56, 64)   18496       ['max_pooling2d_658[0][0]']
#
#  batch_normalization_3543 (Batc  (None, 56, 56, 64)  256         ['conv2d_3403[0][0]']
#  hNormalization)
#
#  activation_3434 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3543[0][0]'
#                                                                  ]
#
#  conv2d_3404 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3434[0][0]']
#
#  batch_normalization_3544 (Batc  (None, 56, 56, 64)  256         ['conv2d_3404[0][0]']
#  hNormalization)
#
#  activation_3435 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3544[0][0]'
#                                                                  ]
#
#  conv2d_3405 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3435[0][0]']
#
#  batch_normalization_3545 (Batc  (None, 56, 56, 64)  256         ['conv2d_3405[0][0]']
#  hNormalization)
#
#  activation_3436 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3545[0][0]'
#                                                                  ]
#
#  conv2d_3406 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3436[0][0]']
#
#  batch_normalization_3546 (Batc  (None, 56, 56, 64)  256         ['conv2d_3406[0][0]']
#  hNormalization)
#
#  activation_3437 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3546[0][0]'
#                                                                  ]
#
#  conv2d_3407 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3437[0][0]']
#
#  batch_normalization_3547 (Batc  (None, 56, 56, 64)  256         ['conv2d_3407[0][0]']
#  hNormalization)
#
#  activation_3438 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3547[0][0]'
#                                                                  ]
#
#  max_pooling2d_659 (MaxPooling2  (None, 28, 28, 64)  0           ['activation_3438[0][0]']
#  D)
#
#  conv2d_3408 (Conv2D)           (None, 28, 28, 128)  73856       ['max_pooling2d_659[0][0]']
#
#  batch_normalization_3548 (Batc  (None, 28, 28, 128)  512        ['conv2d_3408[0][0]']
#  hNormalization)
#
#  activation_3439 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3548[0][0]'
#                                                                  ]
#
#  conv2d_3409 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3439[0][0]']
#
#  batch_normalization_3549 (Batc  (None, 28, 28, 128)  512        ['conv2d_3409[0][0]']
#  hNormalization)
#
#  activation_3440 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3549[0][0]'
#                                                                  ]
#
#  conv2d_3410 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3440[0][0]']
#
#  batch_normalization_3550 (Batc  (None, 28, 28, 128)  512        ['conv2d_3410[0][0]']
#  hNormalization)
#
#  activation_3441 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3550[0][0]'
#                                                                  ]
#
#  conv2d_3411 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3441[0][0]']
#
#  batch_normalization_3551 (Batc  (None, 28, 28, 128)  512        ['conv2d_3411[0][0]']
#  hNormalization)
#
#  activation_3442 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3551[0][0]'
#                                                                  ]
#
#  conv2d_3412 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3442[0][0]']
#
#  batch_normalization_3552 (Batc  (None, 28, 28, 128)  512        ['conv2d_3412[0][0]']
#  hNormalization)
#
#  activation_3443 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3552[0][0]'
#                                                                  ]
#
#  max_pooling2d_660 (MaxPooling2  (None, 14, 14, 128)  0          ['activation_3443[0][0]']
#  D)
#
#  conv2d_3413 (Conv2D)           (None, 14, 14, 256)  295168      ['max_pooling2d_660[0][0]']
#
#  batch_normalization_3553 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3413[0][0]']
#  hNormalization)
#
#  activation_3444 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3553[0][0]'
#                                                                  ]
#
#  conv2d_3414 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3444[0][0]']
#
#  batch_normalization_3554 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3414[0][0]']
#  hNormalization)
#
#  activation_3445 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3554[0][0]'
#                                                                  ]
#
#  conv2d_3415 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3445[0][0]']
#
#  batch_normalization_3555 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3415[0][0]']
#  hNormalization)
#
#  activation_3446 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3555[0][0]'
#                                                                  ]
#
#  conv2d_3416 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3446[0][0]']
#
#  batch_normalization_3556 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3416[0][0]']
#  hNormalization)
#
#  activation_3447 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3556[0][0]'
#                                                                  ]
#
#  conv2d_3417 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3447[0][0]']
#
#  batch_normalization_3557 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3417[0][0]']
#  hNormalization)
#
#  activation_3448 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3557[0][0]'
#                                                                  ]
#
#  conv2d_transpose_258 (Conv2DTr  (None, 28, 28, 128)  131200     ['activation_3448[0][0]']
#  anspose)
#
#  batch_normalization_3558 (Batc  (None, 28, 28, 128)  512        ['conv2d_transpose_258[0][0]']
#  hNormalization)
#
#  activation_3449 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3558[0][0]'
#                                                                  ]
#
#  concatenate_199 (Concatenate)  (None, 28, 28, 256)  0           ['activation_3449[0][0]',
#                                                                   'activation_3443[0][0]']
#
#  conv2d_3418 (Conv2D)           (None, 28, 28, 128)  295040      ['concatenate_199[0][0]']
#
#  batch_normalization_3559 (Batc  (None, 28, 28, 128)  512        ['conv2d_3418[0][0]']
#  hNormalization)
#
#  activation_3450 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3559[0][0]'
#                                                                  ]
#
#  conv2d_3419 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3450[0][0]']
#
#  batch_normalization_3560 (Batc  (None, 28, 28, 128)  512        ['conv2d_3419[0][0]']
#  hNormalization)
#
#  activation_3451 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3560[0][0]'
#                                                                  ]
#
#  conv2d_3420 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3451[0][0]']
#
#  batch_normalization_3561 (Batc  (None, 28, 28, 128)  512        ['conv2d_3420[0][0]']
#  hNormalization)
#
#  activation_3452 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3561[0][0]'
#                                                                  ]
#
#  conv2d_3421 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3452[0][0]']
#
#  batch_normalization_3562 (Batc  (None, 28, 28, 128)  512        ['conv2d_3421[0][0]']
#  hNormalization)
#
#  activation_3453 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3562[0][0]'
#                                                                  ]
#
#  conv2d_3422 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3453[0][0]']
#
#  batch_normalization_3563 (Batc  (None, 28, 28, 128)  512        ['conv2d_3422[0][0]']
#  hNormalization)
#
#  activation_3454 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3563[0][0]'
#                                                                  ]
#
#  conv2d_transpose_259 (Conv2DTr  (None, 56, 56, 64)  32832       ['activation_3454[0][0]']
#  anspose)
#
#  batch_normalization_3564 (Batc  (None, 56, 56, 64)  256         ['conv2d_transpose_259[0][0]']
#  hNormalization)
#
#  activation_3455 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3564[0][0]'
#                                                                  ]
#
#  concatenate_200 (Concatenate)  (None, 56, 56, 128)  0           ['activation_3455[0][0]',
#                                                                   'activation_3438[0][0]']
#
#  conv2d_3423 (Conv2D)           (None, 56, 56, 64)   73792       ['concatenate_200[0][0]']
#
#  batch_normalization_3565 (Batc  (None, 56, 56, 64)  256         ['conv2d_3423[0][0]']
#  hNormalization)
#
#  activation_3456 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3565[0][0]'
#                                                                  ]
#
#  conv2d_3424 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3456[0][0]']
#
#  batch_normalization_3566 (Batc  (None, 56, 56, 64)  256         ['conv2d_3424[0][0]']
#  hNormalization)
#
#  activation_3457 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3566[0][0]'
#                                                                  ]
#
#  conv2d_3425 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3457[0][0]']
#
#  batch_normalization_3567 (Batc  (None, 56, 56, 64)  256         ['conv2d_3425[0][0]']
#  hNormalization)
#
#  activation_3458 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3567[0][0]'
#                                                                  ]
#
#  conv2d_3426 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3458[0][0]']
#
#  batch_normalization_3568 (Batc  (None, 56, 56, 64)  256         ['conv2d_3426[0][0]']
#  hNormalization)
#
#  activation_3459 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3568[0][0]'
#                                                                  ]
#
#  conv2d_3427 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3459[0][0]']
#
#  batch_normalization_3569 (Batc  (None, 56, 56, 64)  256         ['conv2d_3427[0][0]']
#  hNormalization)
#
#  activation_3460 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3569[0][0]'
#                                                                  ]
#
#  conv2d_transpose_260 (Conv2DTr  (None, 112, 112, 32  8224       ['activation_3460[0][0]']
#  anspose)                       )
#
#  batch_normalization_3570 (Batc  (None, 112, 112, 32  128        ['conv2d_transpose_260[0][0]']
#  hNormalization)                )
#
#  activation_3461 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3570[0][0]'
#                                 )                                ]
#
#  concatenate_201 (Concatenate)  (None, 112, 112, 64  0           ['activation_3461[0][0]',
#                                 )                                 'activation_3433[0][0]']
#
#  conv2d_3428 (Conv2D)           (None, 112, 112, 32  18464       ['concatenate_201[0][0]']
#                                 )
#
#  batch_normalization_3571 (Batc  (None, 112, 112, 32  128        ['conv2d_3428[0][0]']
#  hNormalization)                )
#
#  activation_3462 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3571[0][0]'
#                                 )                                ]
#
#  conv2d_3429 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3462[0][0]']
#                                 )
#
#  batch_normalization_3572 (Batc  (None, 112, 112, 32  128        ['conv2d_3429[0][0]']
#  hNormalization)                )
#
#  activation_3463 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3572[0][0]'
#                                 )                                ]
#
#  conv2d_3430 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3463[0][0]']
#                                 )
#
#  batch_normalization_3573 (Batc  (None, 112, 112, 32  128        ['conv2d_3430[0][0]']
#  hNormalization)                )
#
#  activation_3464 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3573[0][0]'
#                                 )                                ]
#
#  conv2d_3431 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3464[0][0]']
#                                 )
#
#  batch_normalization_3574 (Batc  (None, 112, 112, 32  128        ['conv2d_3431[0][0]']
#  hNormalization)                )
#
#  activation_3465 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3574[0][0]'
#                                 )                                ]
#
#  conv2d_3432 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3465[0][0]']
#                                 )
#
#  batch_normalization_3575 (Batc  (None, 112, 112, 32  128        ['conv2d_3432[0][0]']
#  hNormalization)                )
#
#  activation_3466 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3575[0][0]'
#                                 )                                ]
#
#  conv2d_transpose_261 (Conv2DTr  (None, 224, 224, 16  2064       ['activation_3466[0][0]']
#  anspose)                       )
#
#  batch_normalization_3576 (Batc  (None, 224, 224, 16  64         ['conv2d_transpose_261[0][0]']
#  hNormalization)                )
#
#  activation_3467 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3576[0][0]'
#                                 )                                ]
#
#  concatenate_202 (Concatenate)  (None, 224, 224, 32  0           ['activation_3467[0][0]',
#                                 )                                 'activation_3428[0][0]']
#
#  conv2d_3433 (Conv2D)           (None, 224, 224, 16  4624        ['concatenate_202[0][0]']
#                                 )
#
#  batch_normalization_3577 (Batc  (None, 224, 224, 16  64         ['conv2d_3433[0][0]']
#  hNormalization)                )
#
#  activation_3468 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3577[0][0]'
#                                 )                                ]
#
#  conv2d_3434 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3468[0][0]']
#                                 )
#
#  batch_normalization_3578 (Batc  (None, 224, 224, 16  64         ['conv2d_3434[0][0]']
#  hNormalization)                )
#
#  activation_3469 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3578[0][0]'
#                                 )                                ]
#
#  conv2d_3435 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3469[0][0]']
#                                 )
#
#  batch_normalization_3579 (Batc  (None, 224, 224, 16  64         ['conv2d_3435[0][0]']
#  hNormalization)                )
#
#  activation_3470 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3579[0][0]'
#                                 )                                ]
#
#  conv2d_3436 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3470[0][0]']
#                                 )
#
#  batch_normalization_3580 (Batc  (None, 224, 224, 16  64         ['conv2d_3436[0][0]']
#  hNormalization)                )
#
#  activation_3471 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3580[0][0]'
#                                 )                                ]
#
#  conv2d_3437 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3471[0][0]']
#                                 )
#
#  batch_normalization_3581 (Batc  (None, 224, 224, 16  64         ['conv2d_3437[0][0]']
#  hNormalization)                )
#
#  activation_3472 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3581[0][0]'
#                                 )                                ]
#
#  conv2d_3438 (Conv2D)           (None, 224, 224, 2)  34          ['activation_3472[0][0]']
#
#  activation_3473 (Activation)   (None, 224, 224, 2)  0           ['conv2d_3438[0][0]']
#
# ==================================================================================================
# Total params: 4,903,522
# Trainable params: 4,895,682
# Non-trainable params: 7,840
# __________________________________________________________________________________________________

# %% [markdown]
# # Attention U-Net

# %%
def attention_block( input_block, gate, ks=(1,1) ):
  x = Conv2D( NF, ks )(input_block)
  x = BatchNormalization()(x)

  g = Conv2D( NF, ks )(gate)
  g = BatchNormalization()(g)

  att_map = Add()( [g, x] )
  att_map = Activation( 'relu' )(att_map)

  att_map = Conv2D( 1, ks )(att_map)
  att_map = Activation( 'sigmoid')(att_map)
  x = Multiply()( [input_block, att_map ] )

  return x

o1 = conv_block( inp, NF,    ks_s ); p1 = MaxPooling2D()( o1 )
o2 = conv_block( p1,  NF*2,  ks_s ); p2 = MaxPooling2D()( o2 )
o3 = conv_block( p2,  NF*4,  ks_s ); p3 = MaxPooling2D()( o3 )
o4 = conv_block( p3,  NF*8,  ks_s ); p4 = MaxPooling2D()( o4 )
o5 = conv_block( p4,  NF*16, ks_s ); p5 = MaxPooling2D()( o5 )

c6=attention_block( deconv_block( o5, NF*8, strides=(2,2) ), o4)
c7=attention_block( deconv_block( o6, NF*4, strides=(2,2) ), o3)
c8=attention_block( deconv_block( o7, NF*2, strides=(2,2) ), o2)
c9=attention_block( deconv_block( o8, NF*1, strides=(2,2) ), o1)

o6 = conv_block( Concatenate()( [c6, o4] ), NF*8, ks_s )
o7 = conv_block( Concatenate()( [c7, o3] ), NF*4, ks_s )
o8 = conv_block( Concatenate()( [c8, o2] ), NF*2, ks_s )
o9 = conv_block( Concatenate()( [c9, o1] ), NF*1, ks_s )

out = Activation( AC )( Conv2D( 3, 1 )( o9 ) )
att_model = Model(inp, outputs=out )

# %%
att_model.summary()
# Out:
# Model: "model_36"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_114 (InputLayer)         [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_3393 (Conv2D)           (None, 224, 224, 16  448         ['input_114[0][0]']
#                                 )
#
#  batch_normalization_3533 (Batc  (None, 224, 224, 16  64         ['conv2d_3393[0][0]']
#  hNormalization)                )
#
#  activation_3424 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3533[0][0]'
#                                 )                                ]
#
#  conv2d_3394 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3424[0][0]']
#                                 )
#
#  batch_normalization_3534 (Batc  (None, 224, 224, 16  64         ['conv2d_3394[0][0]']
#  hNormalization)                )
#
#  activation_3425 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3534[0][0]'
#                                 )                                ]
#
#  conv2d_3395 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3425[0][0]']
#                                 )
#
#  batch_normalization_3535 (Batc  (None, 224, 224, 16  64         ['conv2d_3395[0][0]']
#  hNormalization)                )
#
#  activation_3426 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3535[0][0]'
#                                 )                                ]
#
#  conv2d_3396 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3426[0][0]']
#                                 )
#
#  batch_normalization_3536 (Batc  (None, 224, 224, 16  64         ['conv2d_3396[0][0]']
#  hNormalization)                )
#
#  activation_3427 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3536[0][0]'
#                                 )                                ]
#
#  conv2d_3397 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3427[0][0]']
#                                 )
#
#  batch_normalization_3537 (Batc  (None, 224, 224, 16  64         ['conv2d_3397[0][0]']
#  hNormalization)                )
#
#  activation_3428 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3537[0][0]'
#                                 )                                ]
#
#  max_pooling2d_657 (MaxPooling2  (None, 112, 112, 16  0          ['activation_3428[0][0]']
#  D)                             )
#
#  conv2d_3398 (Conv2D)           (None, 112, 112, 32  4640        ['max_pooling2d_657[0][0]']
#                                 )
#
#  batch_normalization_3538 (Batc  (None, 112, 112, 32  128        ['conv2d_3398[0][0]']
#  hNormalization)                )
#
#  activation_3429 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3538[0][0]'
#                                 )                                ]
#
#  conv2d_3399 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3429[0][0]']
#                                 )
#
#  batch_normalization_3539 (Batc  (None, 112, 112, 32  128        ['conv2d_3399[0][0]']
#  hNormalization)                )
#
#  activation_3430 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3539[0][0]'
#                                 )                                ]
#
#  conv2d_3400 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3430[0][0]']
#                                 )
#
#  batch_normalization_3540 (Batc  (None, 112, 112, 32  128        ['conv2d_3400[0][0]']
#  hNormalization)                )
#
#  activation_3431 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3540[0][0]'
#                                 )                                ]
#
#  conv2d_3401 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3431[0][0]']
#                                 )
#
#  batch_normalization_3541 (Batc  (None, 112, 112, 32  128        ['conv2d_3401[0][0]']
#  hNormalization)                )
#
#  activation_3432 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3541[0][0]'
#                                 )                                ]
#
#  conv2d_3402 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3432[0][0]']
#                                 )
#
#  batch_normalization_3542 (Batc  (None, 112, 112, 32  128        ['conv2d_3402[0][0]']
#  hNormalization)                )
#
#  activation_3433 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3542[0][0]'
#                                 )                                ]
#
#  max_pooling2d_658 (MaxPooling2  (None, 56, 56, 32)  0           ['activation_3433[0][0]']
#  D)
#
#  conv2d_3403 (Conv2D)           (None, 56, 56, 64)   18496       ['max_pooling2d_658[0][0]']
#
#  batch_normalization_3543 (Batc  (None, 56, 56, 64)  256         ['conv2d_3403[0][0]']
#  hNormalization)
#
#  activation_3434 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3543[0][0]'
#                                                                  ]
#
#  conv2d_3404 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3434[0][0]']
#
#  batch_normalization_3544 (Batc  (None, 56, 56, 64)  256         ['conv2d_3404[0][0]']
#  hNormalization)
#
#  activation_3435 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3544[0][0]'
#                                                                  ]
#
#  conv2d_3405 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3435[0][0]']
#
#  batch_normalization_3545 (Batc  (None, 56, 56, 64)  256         ['conv2d_3405[0][0]']
#  hNormalization)
#
#  activation_3436 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3545[0][0]'
#                                                                  ]
#
#  conv2d_3406 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3436[0][0]']
#
#  batch_normalization_3546 (Batc  (None, 56, 56, 64)  256         ['conv2d_3406[0][0]']
#  hNormalization)
#
#  activation_3437 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3546[0][0]'
#                                                                  ]
#
#  conv2d_3407 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3437[0][0]']
#
#  batch_normalization_3547 (Batc  (None, 56, 56, 64)  256         ['conv2d_3407[0][0]']
#  hNormalization)
#
#  activation_3438 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3547[0][0]'
#                                                                  ]
#
#  max_pooling2d_659 (MaxPooling2  (None, 28, 28, 64)  0           ['activation_3438[0][0]']
#  D)
#
#  conv2d_3408 (Conv2D)           (None, 28, 28, 128)  73856       ['max_pooling2d_659[0][0]']
#
#  batch_normalization_3548 (Batc  (None, 28, 28, 128)  512        ['conv2d_3408[0][0]']
#  hNormalization)
#
#  activation_3439 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3548[0][0]'
#                                                                  ]
#
#  conv2d_3409 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3439[0][0]']
#
#  batch_normalization_3549 (Batc  (None, 28, 28, 128)  512        ['conv2d_3409[0][0]']
#  hNormalization)
#
#  activation_3440 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3549[0][0]'
#                                                                  ]
#
#  conv2d_3410 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3440[0][0]']
#
#  batch_normalization_3550 (Batc  (None, 28, 28, 128)  512        ['conv2d_3410[0][0]']
#  hNormalization)
#
#  activation_3441 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3550[0][0]'
#                                                                  ]
#
#  conv2d_3411 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3441[0][0]']
#
#  batch_normalization_3551 (Batc  (None, 28, 28, 128)  512        ['conv2d_3411[0][0]']
#  hNormalization)
#
#  activation_3442 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3551[0][0]'
#                                                                  ]
#
#  conv2d_3412 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3442[0][0]']
#
#  batch_normalization_3552 (Batc  (None, 28, 28, 128)  512        ['conv2d_3412[0][0]']
#  hNormalization)
#
#  activation_3443 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3552[0][0]'
#                                                                  ]
#
#  max_pooling2d_660 (MaxPooling2  (None, 14, 14, 128)  0          ['activation_3443[0][0]']
#  D)
#
#  conv2d_3413 (Conv2D)           (None, 14, 14, 256)  295168      ['max_pooling2d_660[0][0]']
#
#  batch_normalization_3553 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3413[0][0]']
#  hNormalization)
#
#  activation_3444 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3553[0][0]'
#                                                                  ]
#
#  conv2d_3414 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3444[0][0]']
#
#  batch_normalization_3554 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3414[0][0]']
#  hNormalization)
#
#  activation_3445 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3554[0][0]'
#                                                                  ]
#
#  conv2d_3415 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3445[0][0]']
#
#  batch_normalization_3555 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3415[0][0]']
#  hNormalization)
#
#  activation_3446 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3555[0][0]'
#                                                                  ]
#
#  conv2d_3416 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3446[0][0]']
#
#  batch_normalization_3556 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3416[0][0]']
#  hNormalization)
#
#  activation_3447 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3556[0][0]'
#                                                                  ]
#
#  conv2d_3417 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3447[0][0]']
#
#  batch_normalization_3557 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3417[0][0]']
#  hNormalization)
#
#  activation_3448 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3557[0][0]'
#                                                                  ]
#
#  conv2d_transpose_258 (Conv2DTr  (None, 28, 28, 128)  131200     ['activation_3448[0][0]']
#  anspose)
#
#  batch_normalization_3558 (Batc  (None, 28, 28, 128)  512        ['conv2d_transpose_258[0][0]']
#  hNormalization)
#
#  activation_3449 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3558[0][0]'
#                                                                  ]
#
#  concatenate_199 (Concatenate)  (None, 28, 28, 256)  0           ['activation_3449[0][0]',
#                                                                   'activation_3443[0][0]']
#
#  conv2d_3418 (Conv2D)           (None, 28, 28, 128)  295040      ['concatenate_199[0][0]']
#
#  batch_normalization_3559 (Batc  (None, 28, 28, 128)  512        ['conv2d_3418[0][0]']
#  hNormalization)
#
#  activation_3450 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3559[0][0]'
#                                                                  ]
#
#  conv2d_3419 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3450[0][0]']
#
#  batch_normalization_3560 (Batc  (None, 28, 28, 128)  512        ['conv2d_3419[0][0]']
#  hNormalization)
#
#  activation_3451 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3560[0][0]'
#                                                                  ]
#
#  conv2d_3420 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3451[0][0]']
#
#  batch_normalization_3561 (Batc  (None, 28, 28, 128)  512        ['conv2d_3420[0][0]']
#  hNormalization)
#
#  activation_3452 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3561[0][0]'
#                                                                  ]
#
#  conv2d_3421 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3452[0][0]']
#
#  batch_normalization_3562 (Batc  (None, 28, 28, 128)  512        ['conv2d_3421[0][0]']
#  hNormalization)
#
#  activation_3453 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3562[0][0]'
#                                                                  ]
#
#  conv2d_3422 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3453[0][0]']
#
#  batch_normalization_3563 (Batc  (None, 28, 28, 128)  512        ['conv2d_3422[0][0]']
#  hNormalization)
#
#  activation_3454 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3563[0][0]'
#                                                                  ]
#
#  conv2d_transpose_259 (Conv2DTr  (None, 56, 56, 64)  32832       ['activation_3454[0][0]']
#  anspose)
#
#  batch_normalization_3564 (Batc  (None, 56, 56, 64)  256         ['conv2d_transpose_259[0][0]']
#  hNormalization)
#
#  activation_3455 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3564[0][0]'
#                                                                  ]
#
#  concatenate_200 (Concatenate)  (None, 56, 56, 128)  0           ['activation_3455[0][0]',
#                                                                   'activation_3438[0][0]']
#
#  conv2d_3423 (Conv2D)           (None, 56, 56, 64)   73792       ['concatenate_200[0][0]']
#
#  batch_normalization_3565 (Batc  (None, 56, 56, 64)  256         ['conv2d_3423[0][0]']
#  hNormalization)
#
#  activation_3456 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3565[0][0]'
#                                                                  ]
#
#  conv2d_3424 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3456[0][0]']
#
#  batch_normalization_3566 (Batc  (None, 56, 56, 64)  256         ['conv2d_3424[0][0]']
#  hNormalization)
#
#  activation_3457 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3566[0][0]'
#                                                                  ]
#
#  conv2d_3425 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3457[0][0]']
#
#  batch_normalization_3567 (Batc  (None, 56, 56, 64)  256         ['conv2d_3425[0][0]']
#  hNormalization)
#
#  activation_3458 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3567[0][0]'
#                                                                  ]
#
#  conv2d_3426 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3458[0][0]']
#
#  batch_normalization_3568 (Batc  (None, 56, 56, 64)  256         ['conv2d_3426[0][0]']
#  hNormalization)
#
#  activation_3459 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3568[0][0]'
#                                                                  ]
#
#  conv2d_3427 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3459[0][0]']
#
#  batch_normalization_3569 (Batc  (None, 56, 56, 64)  256         ['conv2d_3427[0][0]']
#  hNormalization)
#
#  activation_3460 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3569[0][0]'
#                                                                  ]
#
#  conv2d_transpose_260 (Conv2DTr  (None, 112, 112, 32  8224       ['activation_3460[0][0]']
#  anspose)                       )
#
#  batch_normalization_3570 (Batc  (None, 112, 112, 32  128        ['conv2d_transpose_260[0][0]']
#  hNormalization)                )
#
#  activation_3461 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3570[0][0]'
#                                 )                                ]
#
#  concatenate_201 (Concatenate)  (None, 112, 112, 64  0           ['activation_3461[0][0]',
#                                 )                                 'activation_3433[0][0]']
#
#  conv2d_3428 (Conv2D)           (None, 112, 112, 32  18464       ['concatenate_201[0][0]']
#                                 )
#
#  batch_normalization_3571 (Batc  (None, 112, 112, 32  128        ['conv2d_3428[0][0]']
#  hNormalization)                )
#
#  activation_3462 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3571[0][0]'
#                                 )                                ]
#
#  conv2d_3429 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3462[0][0]']
#                                 )
#
#  conv2d_3439 (Conv2D)           (None, 224, 224, 16  448         ['input_114[0][0]']
#                                 )
#
#  batch_normalization_3572 (Batc  (None, 112, 112, 32  128        ['conv2d_3429[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3582 (Batc  (None, 224, 224, 16  64         ['conv2d_3439[0][0]']
#  hNormalization)                )
#
#  activation_3463 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3572[0][0]'
#                                 )                                ]
#
#  activation_3474 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3582[0][0]'
#                                 )                                ]
#
#  conv2d_3430 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3463[0][0]']
#                                 )
#
#  conv2d_3440 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3474[0][0]']
#                                 )
#
#  batch_normalization_3573 (Batc  (None, 112, 112, 32  128        ['conv2d_3430[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3583 (Batc  (None, 224, 224, 16  64         ['conv2d_3440[0][0]']
#  hNormalization)                )
#
#  activation_3464 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3573[0][0]'
#                                 )                                ]
#
#  activation_3475 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3583[0][0]'
#                                 )                                ]
#
#  conv2d_3431 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3464[0][0]']
#                                 )
#
#  conv2d_3441 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3475[0][0]']
#                                 )
#
#  batch_normalization_3574 (Batc  (None, 112, 112, 32  128        ['conv2d_3431[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3584 (Batc  (None, 224, 224, 16  64         ['conv2d_3441[0][0]']
#  hNormalization)                )
#
#  activation_3465 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3574[0][0]'
#                                 )                                ]
#
#  activation_3476 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3584[0][0]'
#                                 )                                ]
#
#  conv2d_3432 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3465[0][0]']
#                                 )
#
#  conv2d_3442 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3476[0][0]']
#                                 )
#
#  batch_normalization_3575 (Batc  (None, 112, 112, 32  128        ['conv2d_3432[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3585 (Batc  (None, 224, 224, 16  64         ['conv2d_3442[0][0]']
#  hNormalization)                )
#
#  activation_3466 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3575[0][0]'
#                                 )                                ]
#
#  activation_3477 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3585[0][0]'
#                                 )                                ]
#
#  conv2d_transpose_265 (Conv2DTr  (None, 224, 224, 16  2064       ['activation_3466[0][0]']
#  anspose)                       )
#
#  conv2d_3443 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3477[0][0]']
#                                 )
#
#  batch_normalization_3616 (Batc  (None, 224, 224, 16  64         ['conv2d_transpose_265[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3586 (Batc  (None, 224, 224, 16  64         ['conv2d_3443[0][0]']
#  hNormalization)                )
#
#  activation_3508 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3616[0][0]'
#                                 )                                ]
#
#  activation_3478 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3586[0][0]'
#                                 )                                ]
#
#  conv2d_3474 (Conv2D)           (None, 224, 224, 16  272         ['activation_3478[0][0]']
#                                 )
#
#  conv2d_3473 (Conv2D)           (None, 224, 224, 16  272         ['activation_3508[0][0]']
#                                 )
#
#  batch_normalization_3618 (Batc  (None, 224, 224, 16  64         ['conv2d_3474[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3617 (Batc  (None, 224, 224, 16  64         ['conv2d_3473[0][0]']
#  hNormalization)                )
#
#  add_423 (Add)                  (None, 224, 224, 16  0           ['batch_normalization_3618[0][0]'
#                                 )                                , 'batch_normalization_3617[0][0]
#                                                                  ']
#
#  activation_3509 (Activation)   (None, 224, 224, 16  0           ['add_423[0][0]']
#                                 )
#
#  conv2d_3475 (Conv2D)           (None, 224, 224, 1)  17          ['activation_3509[0][0]']
#
#  activation_3510 (Activation)   (None, 224, 224, 1)  0           ['conv2d_3475[0][0]']
#
#  multiply_47 (Multiply)         (None, 224, 224, 16  0           ['activation_3508[0][0]',
#                                 )                                 'activation_3510[0][0]']
#
#  concatenate_206 (Concatenate)  (None, 224, 224, 32  0           ['multiply_47[0][0]',
#                                 )                                 'activation_3478[0][0]']
#
#  conv2d_3491 (Conv2D)           (None, 224, 224, 16  4624        ['concatenate_206[0][0]']
#                                 )
#
#  batch_normalization_3634 (Batc  (None, 224, 224, 16  64         ['conv2d_3491[0][0]']
#  hNormalization)                )
#
#  activation_3526 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3634[0][0]'
#                                 )                                ]
#
#  conv2d_3492 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3526[0][0]']
#                                 )
#
#  batch_normalization_3635 (Batc  (None, 224, 224, 16  64         ['conv2d_3492[0][0]']
#  hNormalization)                )
#
#  activation_3527 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3635[0][0]'
#                                 )                                ]
#
#  conv2d_3493 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3527[0][0]']
#                                 )
#
#  batch_normalization_3636 (Batc  (None, 224, 224, 16  64         ['conv2d_3493[0][0]']
#  hNormalization)                )
#
#  activation_3528 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3636[0][0]'
#                                 )                                ]
#
#  conv2d_3494 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3528[0][0]']
#                                 )
#
#  batch_normalization_3637 (Batc  (None, 224, 224, 16  64         ['conv2d_3494[0][0]']
#  hNormalization)                )
#
#  activation_3529 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3637[0][0]'
#                                 )                                ]
#
#  conv2d_3495 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3529[0][0]']
#                                 )
#
#  batch_normalization_3638 (Batc  (None, 224, 224, 16  64         ['conv2d_3495[0][0]']
#  hNormalization)                )
#
#  activation_3530 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3638[0][0]'
#                                 )                                ]
#
#  conv2d_3496 (Conv2D)           (None, 224, 224, 3)  51          ['activation_3530[0][0]']
#
#  activation_3531 (Activation)   (None, 224, 224, 3)  0           ['conv2d_3496[0][0]']
#
# ==================================================================================================
# Total params: 4,914,276
# Trainable params: 4,906,212
# Non-trainable params: 8,064
# __________________________________________________________________________________________________

# %% [markdown]
# # [Not finished] W-Net

# %%
def wnet_encoder( inp, NB=5, DO=.2 ):

  for i in range(NB):
    if i==0:
      x = Conv2D( NF, ks )(inp)
    else:
      x = Conv2D( NF, ks )(x)
    x = BatchNormalization()(x)
    x = Conv2D( NF, ks )(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D()(x)

    if i== 2:
      x = Dropout(DO)(x)
  x = Conv2D( NF, ks )(x)

  return x


o= wnet_encoder( inp, )
out = Activation( AC )( Conv2D( 3, ks )( o9 ) )
wnet_model = Model( inp, out)

wnet_model.summary()
# Out:
# Model: "model_37"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_114 (InputLayer)         [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_3393 (Conv2D)           (None, 224, 224, 16  448         ['input_114[0][0]']
#                                 )
#
#  batch_normalization_3533 (Batc  (None, 224, 224, 16  64         ['conv2d_3393[0][0]']
#  hNormalization)                )
#
#  activation_3424 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3533[0][0]'
#                                 )                                ]
#
#  conv2d_3394 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3424[0][0]']
#                                 )
#
#  batch_normalization_3534 (Batc  (None, 224, 224, 16  64         ['conv2d_3394[0][0]']
#  hNormalization)                )
#
#  activation_3425 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3534[0][0]'
#                                 )                                ]
#
#  conv2d_3395 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3425[0][0]']
#                                 )
#
#  batch_normalization_3535 (Batc  (None, 224, 224, 16  64         ['conv2d_3395[0][0]']
#  hNormalization)                )
#
#  activation_3426 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3535[0][0]'
#                                 )                                ]
#
#  conv2d_3396 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3426[0][0]']
#                                 )
#
#  batch_normalization_3536 (Batc  (None, 224, 224, 16  64         ['conv2d_3396[0][0]']
#  hNormalization)                )
#
#  activation_3427 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3536[0][0]'
#                                 )                                ]
#
#  conv2d_3397 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3427[0][0]']
#                                 )
#
#  batch_normalization_3537 (Batc  (None, 224, 224, 16  64         ['conv2d_3397[0][0]']
#  hNormalization)                )
#
#  activation_3428 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3537[0][0]'
#                                 )                                ]
#
#  max_pooling2d_657 (MaxPooling2  (None, 112, 112, 16  0          ['activation_3428[0][0]']
#  D)                             )
#
#  conv2d_3398 (Conv2D)           (None, 112, 112, 32  4640        ['max_pooling2d_657[0][0]']
#                                 )
#
#  batch_normalization_3538 (Batc  (None, 112, 112, 32  128        ['conv2d_3398[0][0]']
#  hNormalization)                )
#
#  activation_3429 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3538[0][0]'
#                                 )                                ]
#
#  conv2d_3399 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3429[0][0]']
#                                 )
#
#  batch_normalization_3539 (Batc  (None, 112, 112, 32  128        ['conv2d_3399[0][0]']
#  hNormalization)                )
#
#  activation_3430 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3539[0][0]'
#                                 )                                ]
#
#  conv2d_3400 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3430[0][0]']
#                                 )
#
#  batch_normalization_3540 (Batc  (None, 112, 112, 32  128        ['conv2d_3400[0][0]']
#  hNormalization)                )
#
#  activation_3431 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3540[0][0]'
#                                 )                                ]
#
#  conv2d_3401 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3431[0][0]']
#                                 )
#
#  batch_normalization_3541 (Batc  (None, 112, 112, 32  128        ['conv2d_3401[0][0]']
#  hNormalization)                )
#
#  activation_3432 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3541[0][0]'
#                                 )                                ]
#
#  conv2d_3402 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3432[0][0]']
#                                 )
#
#  batch_normalization_3542 (Batc  (None, 112, 112, 32  128        ['conv2d_3402[0][0]']
#  hNormalization)                )
#
#  activation_3433 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3542[0][0]'
#                                 )                                ]
#
#  max_pooling2d_658 (MaxPooling2  (None, 56, 56, 32)  0           ['activation_3433[0][0]']
#  D)
#
#  conv2d_3403 (Conv2D)           (None, 56, 56, 64)   18496       ['max_pooling2d_658[0][0]']
#
#  batch_normalization_3543 (Batc  (None, 56, 56, 64)  256         ['conv2d_3403[0][0]']
#  hNormalization)
#
#  activation_3434 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3543[0][0]'
#                                                                  ]
#
#  conv2d_3404 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3434[0][0]']
#
#  batch_normalization_3544 (Batc  (None, 56, 56, 64)  256         ['conv2d_3404[0][0]']
#  hNormalization)
#
#  activation_3435 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3544[0][0]'
#                                                                  ]
#
#  conv2d_3405 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3435[0][0]']
#
#  batch_normalization_3545 (Batc  (None, 56, 56, 64)  256         ['conv2d_3405[0][0]']
#  hNormalization)
#
#  activation_3436 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3545[0][0]'
#                                                                  ]
#
#  conv2d_3406 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3436[0][0]']
#
#  batch_normalization_3546 (Batc  (None, 56, 56, 64)  256         ['conv2d_3406[0][0]']
#  hNormalization)
#
#  activation_3437 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3546[0][0]'
#                                                                  ]
#
#  conv2d_3407 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3437[0][0]']
#
#  batch_normalization_3547 (Batc  (None, 56, 56, 64)  256         ['conv2d_3407[0][0]']
#  hNormalization)
#
#  activation_3438 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3547[0][0]'
#                                                                  ]
#
#  max_pooling2d_659 (MaxPooling2  (None, 28, 28, 64)  0           ['activation_3438[0][0]']
#  D)
#
#  conv2d_3408 (Conv2D)           (None, 28, 28, 128)  73856       ['max_pooling2d_659[0][0]']
#
#  batch_normalization_3548 (Batc  (None, 28, 28, 128)  512        ['conv2d_3408[0][0]']
#  hNormalization)
#
#  activation_3439 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3548[0][0]'
#                                                                  ]
#
#  conv2d_3409 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3439[0][0]']
#
#  batch_normalization_3549 (Batc  (None, 28, 28, 128)  512        ['conv2d_3409[0][0]']
#  hNormalization)
#
#  activation_3440 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3549[0][0]'
#                                                                  ]
#
#  conv2d_3410 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3440[0][0]']
#
#  batch_normalization_3550 (Batc  (None, 28, 28, 128)  512        ['conv2d_3410[0][0]']
#  hNormalization)
#
#  activation_3441 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3550[0][0]'
#                                                                  ]
#
#  conv2d_3411 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3441[0][0]']
#
#  batch_normalization_3551 (Batc  (None, 28, 28, 128)  512        ['conv2d_3411[0][0]']
#  hNormalization)
#
#  activation_3442 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3551[0][0]'
#                                                                  ]
#
#  conv2d_3412 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3442[0][0]']
#
#  batch_normalization_3552 (Batc  (None, 28, 28, 128)  512        ['conv2d_3412[0][0]']
#  hNormalization)
#
#  activation_3443 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3552[0][0]'
#                                                                  ]
#
#  max_pooling2d_660 (MaxPooling2  (None, 14, 14, 128)  0          ['activation_3443[0][0]']
#  D)
#
#  conv2d_3413 (Conv2D)           (None, 14, 14, 256)  295168      ['max_pooling2d_660[0][0]']
#
#  batch_normalization_3553 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3413[0][0]']
#  hNormalization)
#
#  activation_3444 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3553[0][0]'
#                                                                  ]
#
#  conv2d_3414 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3444[0][0]']
#
#  batch_normalization_3554 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3414[0][0]']
#  hNormalization)
#
#  activation_3445 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3554[0][0]'
#                                                                  ]
#
#  conv2d_3415 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3445[0][0]']
#
#  batch_normalization_3555 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3415[0][0]']
#  hNormalization)
#
#  activation_3446 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3555[0][0]'
#                                                                  ]
#
#  conv2d_3416 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3446[0][0]']
#
#  batch_normalization_3556 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3416[0][0]']
#  hNormalization)
#
#  activation_3447 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3556[0][0]'
#                                                                  ]
#
#  conv2d_3417 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3447[0][0]']
#
#  batch_normalization_3557 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3417[0][0]']
#  hNormalization)
#
#  activation_3448 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3557[0][0]'
#                                                                  ]
#
#  conv2d_transpose_258 (Conv2DTr  (None, 28, 28, 128)  131200     ['activation_3448[0][0]']
#  anspose)
#
#  batch_normalization_3558 (Batc  (None, 28, 28, 128)  512        ['conv2d_transpose_258[0][0]']
#  hNormalization)
#
#  activation_3449 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3558[0][0]'
#                                                                  ]
#
#  concatenate_199 (Concatenate)  (None, 28, 28, 256)  0           ['activation_3449[0][0]',
#                                                                   'activation_3443[0][0]']
#
#  conv2d_3418 (Conv2D)           (None, 28, 28, 128)  295040      ['concatenate_199[0][0]']
#
#  batch_normalization_3559 (Batc  (None, 28, 28, 128)  512        ['conv2d_3418[0][0]']
#  hNormalization)
#
#  activation_3450 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3559[0][0]'
#                                                                  ]
#
#  conv2d_3419 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3450[0][0]']
#
#  batch_normalization_3560 (Batc  (None, 28, 28, 128)  512        ['conv2d_3419[0][0]']
#  hNormalization)
#
#  activation_3451 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3560[0][0]'
#                                                                  ]
#
#  conv2d_3420 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3451[0][0]']
#
#  batch_normalization_3561 (Batc  (None, 28, 28, 128)  512        ['conv2d_3420[0][0]']
#  hNormalization)
#
#  activation_3452 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3561[0][0]'
#                                                                  ]
#
#  conv2d_3421 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3452[0][0]']
#
#  batch_normalization_3562 (Batc  (None, 28, 28, 128)  512        ['conv2d_3421[0][0]']
#  hNormalization)
#
#  activation_3453 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3562[0][0]'
#                                                                  ]
#
#  conv2d_3422 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3453[0][0]']
#
#  batch_normalization_3563 (Batc  (None, 28, 28, 128)  512        ['conv2d_3422[0][0]']
#  hNormalization)
#
#  activation_3454 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3563[0][0]'
#                                                                  ]
#
#  conv2d_transpose_259 (Conv2DTr  (None, 56, 56, 64)  32832       ['activation_3454[0][0]']
#  anspose)
#
#  batch_normalization_3564 (Batc  (None, 56, 56, 64)  256         ['conv2d_transpose_259[0][0]']
#  hNormalization)
#
#  activation_3455 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3564[0][0]'
#                                                                  ]
#
#  concatenate_200 (Concatenate)  (None, 56, 56, 128)  0           ['activation_3455[0][0]',
#                                                                   'activation_3438[0][0]']
#
#  conv2d_3423 (Conv2D)           (None, 56, 56, 64)   73792       ['concatenate_200[0][0]']
#
#  batch_normalization_3565 (Batc  (None, 56, 56, 64)  256         ['conv2d_3423[0][0]']
#  hNormalization)
#
#  activation_3456 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3565[0][0]'
#                                                                  ]
#
#  conv2d_3424 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3456[0][0]']
#
#  batch_normalization_3566 (Batc  (None, 56, 56, 64)  256         ['conv2d_3424[0][0]']
#  hNormalization)
#
#  activation_3457 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3566[0][0]'
#                                                                  ]
#
#  conv2d_3425 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3457[0][0]']
#
#  batch_normalization_3567 (Batc  (None, 56, 56, 64)  256         ['conv2d_3425[0][0]']
#  hNormalization)
#
#  activation_3458 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3567[0][0]'
#                                                                  ]
#
#  conv2d_3426 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3458[0][0]']
#
#  batch_normalization_3568 (Batc  (None, 56, 56, 64)  256         ['conv2d_3426[0][0]']
#  hNormalization)
#
#  activation_3459 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3568[0][0]'
#                                                                  ]
#
#  conv2d_3427 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3459[0][0]']
#
#  batch_normalization_3569 (Batc  (None, 56, 56, 64)  256         ['conv2d_3427[0][0]']
#  hNormalization)
#
#  activation_3460 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3569[0][0]'
#                                                                  ]
#
#  conv2d_transpose_260 (Conv2DTr  (None, 112, 112, 32  8224       ['activation_3460[0][0]']
#  anspose)                       )
#
#  batch_normalization_3570 (Batc  (None, 112, 112, 32  128        ['conv2d_transpose_260[0][0]']
#  hNormalization)                )
#
#  activation_3461 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3570[0][0]'
#                                 )                                ]
#
#  concatenate_201 (Concatenate)  (None, 112, 112, 64  0           ['activation_3461[0][0]',
#                                 )                                 'activation_3433[0][0]']
#
#  conv2d_3428 (Conv2D)           (None, 112, 112, 32  18464       ['concatenate_201[0][0]']
#                                 )
#
#  batch_normalization_3571 (Batc  (None, 112, 112, 32  128        ['conv2d_3428[0][0]']
#  hNormalization)                )
#
#  activation_3462 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3571[0][0]'
#                                 )                                ]
#
#  conv2d_3429 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3462[0][0]']
#                                 )
#
#  conv2d_3439 (Conv2D)           (None, 224, 224, 16  448         ['input_114[0][0]']
#                                 )
#
#  batch_normalization_3572 (Batc  (None, 112, 112, 32  128        ['conv2d_3429[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3582 (Batc  (None, 224, 224, 16  64         ['conv2d_3439[0][0]']
#  hNormalization)                )
#
#  activation_3463 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3572[0][0]'
#                                 )                                ]
#
#  activation_3474 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3582[0][0]'
#                                 )                                ]
#
#  conv2d_3430 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3463[0][0]']
#                                 )
#
#  conv2d_3440 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3474[0][0]']
#                                 )
#
#  batch_normalization_3573 (Batc  (None, 112, 112, 32  128        ['conv2d_3430[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3583 (Batc  (None, 224, 224, 16  64         ['conv2d_3440[0][0]']
#  hNormalization)                )
#
#  activation_3464 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3573[0][0]'
#                                 )                                ]
#
#  activation_3475 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3583[0][0]'
#                                 )                                ]
#
#  conv2d_3431 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3464[0][0]']
#                                 )
#
#  conv2d_3441 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3475[0][0]']
#                                 )
#
#  batch_normalization_3574 (Batc  (None, 112, 112, 32  128        ['conv2d_3431[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3584 (Batc  (None, 224, 224, 16  64         ['conv2d_3441[0][0]']
#  hNormalization)                )
#
#  activation_3465 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3574[0][0]'
#                                 )                                ]
#
#  activation_3476 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3584[0][0]'
#                                 )                                ]
#
#  conv2d_3432 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3465[0][0]']
#                                 )
#
#  conv2d_3442 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3476[0][0]']
#                                 )
#
#  batch_normalization_3575 (Batc  (None, 112, 112, 32  128        ['conv2d_3432[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3585 (Batc  (None, 224, 224, 16  64         ['conv2d_3442[0][0]']
#  hNormalization)                )
#
#  activation_3466 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3575[0][0]'
#                                 )                                ]
#
#  activation_3477 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3585[0][0]'
#                                 )                                ]
#
#  conv2d_transpose_265 (Conv2DTr  (None, 224, 224, 16  2064       ['activation_3466[0][0]']
#  anspose)                       )
#
#  conv2d_3443 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3477[0][0]']
#                                 )
#
#  batch_normalization_3616 (Batc  (None, 224, 224, 16  64         ['conv2d_transpose_265[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3586 (Batc  (None, 224, 224, 16  64         ['conv2d_3443[0][0]']
#  hNormalization)                )
#
#  activation_3508 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3616[0][0]'
#                                 )                                ]
#
#  activation_3478 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3586[0][0]'
#                                 )                                ]
#
#  conv2d_3474 (Conv2D)           (None, 224, 224, 16  272         ['activation_3478[0][0]']
#                                 )
#
#  conv2d_3473 (Conv2D)           (None, 224, 224, 16  272         ['activation_3508[0][0]']
#                                 )
#
#  batch_normalization_3618 (Batc  (None, 224, 224, 16  64         ['conv2d_3474[0][0]']
#  hNormalization)                )
#
#  batch_normalization_3617 (Batc  (None, 224, 224, 16  64         ['conv2d_3473[0][0]']
#  hNormalization)                )
#
#  add_423 (Add)                  (None, 224, 224, 16  0           ['batch_normalization_3618[0][0]'
#                                 )                                , 'batch_normalization_3617[0][0]
#                                                                  ']
#
#  activation_3509 (Activation)   (None, 224, 224, 16  0           ['add_423[0][0]']
#                                 )
#
#  conv2d_3475 (Conv2D)           (None, 224, 224, 1)  17          ['activation_3509[0][0]']
#
#  activation_3510 (Activation)   (None, 224, 224, 1)  0           ['conv2d_3475[0][0]']
#
#  multiply_47 (Multiply)         (None, 224, 224, 16  0           ['activation_3508[0][0]',
#                                 )                                 'activation_3510[0][0]']
#
#  concatenate_206 (Concatenate)  (None, 224, 224, 32  0           ['multiply_47[0][0]',
#                                 )                                 'activation_3478[0][0]']
#
#  conv2d_3491 (Conv2D)           (None, 224, 224, 16  4624        ['concatenate_206[0][0]']
#                                 )
#
#  batch_normalization_3634 (Batc  (None, 224, 224, 16  64         ['conv2d_3491[0][0]']
#  hNormalization)                )
#
#  activation_3526 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3634[0][0]'
#                                 )                                ]
#
#  conv2d_3492 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3526[0][0]']
#                                 )
#
#  batch_normalization_3635 (Batc  (None, 224, 224, 16  64         ['conv2d_3492[0][0]']
#  hNormalization)                )
#
#  activation_3527 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3635[0][0]'
#                                 )                                ]
#
#  conv2d_3493 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3527[0][0]']
#                                 )
#
#  batch_normalization_3636 (Batc  (None, 224, 224, 16  64         ['conv2d_3493[0][0]']
#  hNormalization)                )
#
#  activation_3528 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3636[0][0]'
#                                 )                                ]
#
#  conv2d_3494 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3528[0][0]']
#                                 )
#
#  batch_normalization_3637 (Batc  (None, 224, 224, 16  64         ['conv2d_3494[0][0]']
#  hNormalization)                )
#
#  activation_3529 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3637[0][0]'
#                                 )                                ]
#
#  conv2d_3495 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3529[0][0]']
#                                 )
#
#  batch_normalization_3638 (Batc  (None, 224, 224, 16  64         ['conv2d_3495[0][0]']
#  hNormalization)                )
#
#  activation_3530 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3638[0][0]'
#                                 )                                ]
#
#  conv2d_3508 (Conv2D)           (None, 222, 222, 3)  435         ['activation_3530[0][0]']
#
#  activation_3532 (Activation)   (None, 222, 222, 3)  0           ['conv2d_3508[0][0]']
#
# ==================================================================================================
# Total params: 4,914,660
# Trainable params: 4,906,596
# Non-trainable params: 8,064
# __________________________________________________________________________________________________

# %% [markdown]
#  # Residual U-Net

# %%
def residual_block( x, NF, KS, strides=(1,1) ):

  x = Conv2D( NF, KS[0], padding='same', strides=strides )(x)
  x = BatchNormalization()(x)
  x = Activation( 'relu' )(x)

  o = stack_bn_act( x, NF, KS[1:], strides=(1,1) )    # one less
  x = Add()( [o, x] )
  return x

NC=2
ks_s = [3]*NC
o1 = residual_block( inp, NF*1,  ks_s ); p1= MaxPooling2D( (2,2) )( o1 )
o2 = residual_block(  p1, NF*2,  ks_s ); p2= MaxPooling2D( (2,2) )( o2 )
o3 = residual_block(  p2, NF*4,  ks_s ); p3= MaxPooling2D( (2,2) )( o3 )
o4 = residual_block(  p3, NF*8,  ks_s ); p4= MaxPooling2D( (2,2) )( o4 )
o5 = residual_block(  p4, NF*16, ks_s );

o6 = concatenate( [deconv_block( o5, NF*8, 2, strides=(2,2) ), o4]); o6 = residual_block( o6, NF*8, ks_s );
o7 = concatenate( [deconv_block( o6, NF*4, 2, strides=(2,2) ), o3]); o7 = residual_block( o7, NF*4, ks_s );
o8 = concatenate( [deconv_block( o7, NF*2, 2, strides=(2,2) ), o2]); o8 = residual_block( o8, NF*2, ks_s );
o9 = concatenate( [deconv_block( o8, NF*1, 2, strides=(2,2) ), o1]); o9 = residual_block( o9, NF*1, ks_s );


out = Activation( AC )( Conv2D( n_slices, 1 )( o9 ) )
model = Model(inp, outputs=out )

# %%
model.summary()
# Out:
# Model: "model_38"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_114 (InputLayer)         [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_3509 (Conv2D)           (None, 224, 224, 16  448         ['input_114[0][0]']
#                                 )
#
#  batch_normalization_3649 (Batc  (None, 224, 224, 16  64         ['conv2d_3509[0][0]']
#  hNormalization)                )
#
#  activation_3533 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3649[0][0]'
#                                 )                                ]
#
#  conv2d_3510 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3533[0][0]']
#                                 )
#
#  batch_normalization_3650 (Batc  (None, 224, 224, 16  64         ['conv2d_3510[0][0]']
#  hNormalization)                )
#
#  activation_3534 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3650[0][0]'
#                                 )                                ]
#
#  add_424 (Add)                  (None, 224, 224, 16  0           ['activation_3534[0][0]',
#                                 )                                 'activation_3533[0][0]']
#
#  max_pooling2d_672 (MaxPooling2  (None, 112, 112, 16  0          ['add_424[0][0]']
#  D)                             )
#
#  conv2d_3511 (Conv2D)           (None, 112, 112, 32  4640        ['max_pooling2d_672[0][0]']
#                                 )
#
#  batch_normalization_3651 (Batc  (None, 112, 112, 32  128        ['conv2d_3511[0][0]']
#  hNormalization)                )
#
#  activation_3535 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3651[0][0]'
#                                 )                                ]
#
#  conv2d_3512 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3535[0][0]']
#                                 )
#
#  batch_normalization_3652 (Batc  (None, 112, 112, 32  128        ['conv2d_3512[0][0]']
#  hNormalization)                )
#
#  activation_3536 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3652[0][0]'
#                                 )                                ]
#
#  add_425 (Add)                  (None, 112, 112, 32  0           ['activation_3536[0][0]',
#                                 )                                 'activation_3535[0][0]']
#
#  max_pooling2d_673 (MaxPooling2  (None, 56, 56, 32)  0           ['add_425[0][0]']
#  D)
#
#  conv2d_3513 (Conv2D)           (None, 56, 56, 64)   18496       ['max_pooling2d_673[0][0]']
#
#  batch_normalization_3653 (Batc  (None, 56, 56, 64)  256         ['conv2d_3513[0][0]']
#  hNormalization)
#
#  activation_3537 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3653[0][0]'
#                                                                  ]
#
#  conv2d_3514 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3537[0][0]']
#
#  batch_normalization_3654 (Batc  (None, 56, 56, 64)  256         ['conv2d_3514[0][0]']
#  hNormalization)
#
#  activation_3538 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3654[0][0]'
#                                                                  ]
#
#  add_426 (Add)                  (None, 56, 56, 64)   0           ['activation_3538[0][0]',
#                                                                   'activation_3537[0][0]']
#
#  max_pooling2d_674 (MaxPooling2  (None, 28, 28, 64)  0           ['add_426[0][0]']
#  D)
#
#  conv2d_3515 (Conv2D)           (None, 28, 28, 128)  73856       ['max_pooling2d_674[0][0]']
#
#  batch_normalization_3655 (Batc  (None, 28, 28, 128)  512        ['conv2d_3515[0][0]']
#  hNormalization)
#
#  activation_3539 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3655[0][0]'
#                                                                  ]
#
#  conv2d_3516 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3539[0][0]']
#
#  batch_normalization_3656 (Batc  (None, 28, 28, 128)  512        ['conv2d_3516[0][0]']
#  hNormalization)
#
#  activation_3540 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3656[0][0]'
#                                                                  ]
#
#  add_427 (Add)                  (None, 28, 28, 128)  0           ['activation_3540[0][0]',
#                                                                   'activation_3539[0][0]']
#
#  max_pooling2d_675 (MaxPooling2  (None, 14, 14, 128)  0          ['add_427[0][0]']
#  D)
#
#  conv2d_3517 (Conv2D)           (None, 14, 14, 256)  295168      ['max_pooling2d_675[0][0]']
#
#  batch_normalization_3657 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3517[0][0]']
#  hNormalization)
#
#  activation_3541 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3657[0][0]'
#                                                                  ]
#
#  conv2d_3518 (Conv2D)           (None, 14, 14, 256)  590080      ['activation_3541[0][0]']
#
#  batch_normalization_3658 (Batc  (None, 14, 14, 256)  1024       ['conv2d_3518[0][0]']
#  hNormalization)
#
#  activation_3542 (Activation)   (None, 14, 14, 256)  0           ['batch_normalization_3658[0][0]'
#                                                                  ]
#
#  add_428 (Add)                  (None, 14, 14, 256)  0           ['activation_3542[0][0]',
#                                                                   'activation_3541[0][0]']
#
#  conv2d_transpose_266 (Conv2DTr  (None, 28, 28, 128)  131200     ['add_428[0][0]']
#  anspose)
#
#  batch_normalization_3659 (Batc  (None, 28, 28, 128)  512        ['conv2d_transpose_266[0][0]']
#  hNormalization)
#
#  activation_3543 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3659[0][0]'
#                                                                  ]
#
#  concatenate_207 (Concatenate)  (None, 28, 28, 256)  0           ['activation_3543[0][0]',
#                                                                   'add_427[0][0]']
#
#  conv2d_3519 (Conv2D)           (None, 28, 28, 128)  295040      ['concatenate_207[0][0]']
#
#  batch_normalization_3660 (Batc  (None, 28, 28, 128)  512        ['conv2d_3519[0][0]']
#  hNormalization)
#
#  activation_3544 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3660[0][0]'
#                                                                  ]
#
#  conv2d_3520 (Conv2D)           (None, 28, 28, 128)  147584      ['activation_3544[0][0]']
#
#  batch_normalization_3661 (Batc  (None, 28, 28, 128)  512        ['conv2d_3520[0][0]']
#  hNormalization)
#
#  activation_3545 (Activation)   (None, 28, 28, 128)  0           ['batch_normalization_3661[0][0]'
#                                                                  ]
#
#  add_429 (Add)                  (None, 28, 28, 128)  0           ['activation_3545[0][0]',
#                                                                   'activation_3544[0][0]']
#
#  conv2d_transpose_267 (Conv2DTr  (None, 56, 56, 64)  32832       ['add_429[0][0]']
#  anspose)
#
#  batch_normalization_3662 (Batc  (None, 56, 56, 64)  256         ['conv2d_transpose_267[0][0]']
#  hNormalization)
#
#  activation_3546 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3662[0][0]'
#                                                                  ]
#
#  concatenate_208 (Concatenate)  (None, 56, 56, 128)  0           ['activation_3546[0][0]',
#                                                                   'add_426[0][0]']
#
#  conv2d_3521 (Conv2D)           (None, 56, 56, 64)   73792       ['concatenate_208[0][0]']
#
#  batch_normalization_3663 (Batc  (None, 56, 56, 64)  256         ['conv2d_3521[0][0]']
#  hNormalization)
#
#  activation_3547 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3663[0][0]'
#                                                                  ]
#
#  conv2d_3522 (Conv2D)           (None, 56, 56, 64)   36928       ['activation_3547[0][0]']
#
#  batch_normalization_3664 (Batc  (None, 56, 56, 64)  256         ['conv2d_3522[0][0]']
#  hNormalization)
#
#  activation_3548 (Activation)   (None, 56, 56, 64)   0           ['batch_normalization_3664[0][0]'
#                                                                  ]
#
#  add_430 (Add)                  (None, 56, 56, 64)   0           ['activation_3548[0][0]',
#                                                                   'activation_3547[0][0]']
#
#  conv2d_transpose_268 (Conv2DTr  (None, 112, 112, 32  8224       ['add_430[0][0]']
#  anspose)                       )
#
#  batch_normalization_3665 (Batc  (None, 112, 112, 32  128        ['conv2d_transpose_268[0][0]']
#  hNormalization)                )
#
#  activation_3549 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3665[0][0]'
#                                 )                                ]
#
#  concatenate_209 (Concatenate)  (None, 112, 112, 64  0           ['activation_3549[0][0]',
#                                 )                                 'add_425[0][0]']
#
#  conv2d_3523 (Conv2D)           (None, 112, 112, 32  18464       ['concatenate_209[0][0]']
#                                 )
#
#  batch_normalization_3666 (Batc  (None, 112, 112, 32  128        ['conv2d_3523[0][0]']
#  hNormalization)                )
#
#  activation_3550 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3666[0][0]'
#                                 )                                ]
#
#  conv2d_3524 (Conv2D)           (None, 112, 112, 32  9248        ['activation_3550[0][0]']
#                                 )
#
#  batch_normalization_3667 (Batc  (None, 112, 112, 32  128        ['conv2d_3524[0][0]']
#  hNormalization)                )
#
#  activation_3551 (Activation)   (None, 112, 112, 32  0           ['batch_normalization_3667[0][0]'
#                                 )                                ]
#
#  add_431 (Add)                  (None, 112, 112, 32  0           ['activation_3551[0][0]',
#                                 )                                 'activation_3550[0][0]']
#
#  conv2d_transpose_269 (Conv2DTr  (None, 224, 224, 16  2064       ['add_431[0][0]']
#  anspose)                       )
#
#  batch_normalization_3668 (Batc  (None, 224, 224, 16  64         ['conv2d_transpose_269[0][0]']
#  hNormalization)                )
#
#  activation_3552 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3668[0][0]'
#                                 )                                ]
#
#  concatenate_210 (Concatenate)  (None, 224, 224, 32  0           ['activation_3552[0][0]',
#                                 )                                 'add_424[0][0]']
#
#  conv2d_3525 (Conv2D)           (None, 224, 224, 16  4624        ['concatenate_210[0][0]']
#                                 )
#
#  batch_normalization_3669 (Batc  (None, 224, 224, 16  64         ['conv2d_3525[0][0]']
#  hNormalization)                )
#
#  activation_3553 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3669[0][0]'
#                                 )                                ]
#
#  conv2d_3526 (Conv2D)           (None, 224, 224, 16  2320        ['activation_3553[0][0]']
#                                 )
#
#  batch_normalization_3670 (Batc  (None, 224, 224, 16  64         ['conv2d_3526[0][0]']
#  hNormalization)                )
#
#  activation_3554 (Activation)   (None, 224, 224, 16  0           ['batch_normalization_3670[0][0]'
#                                 )                                ]
#
#  add_432 (Add)                  (None, 224, 224, 16  0           ['activation_3554[0][0]',
#                                 )                                 'activation_3553[0][0]']
#
#  conv2d_3527 (Conv2D)           (None, 224, 224, 3)  51          ['add_432[0][0]']
#
#  activation_3555 (Activation)   (None, 224, 224, 3)  0           ['conv2d_3527[0][0]']
#
# ==================================================================================================
# Total params: 1,947,987
# Trainable params: 1,944,563
# Non-trainable params: 3,424
# __________________________________________________________________________________________________

# %% [markdown]
# # [to be cont'd] SE U-Net

# %%
def SE_block( input_block ):
    x = GlobalAveragePoolingND()(input_block) # squeeze-step
    x = Dense( n_outputs//2, activation='relu')(x)
    x = Dense( n_outputs, activation='sigmoid')(x)
    x = Multiply()( [input_block, x ] )   # excite-step
    return x
